# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.- Analisis exploratorio

# %%
df = pd.read_csv('/home/davian/ml-proyects/datasets/breast-cancer.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df.isin([np.inf, -np.inf]).sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df_num = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %% [markdown]
# ### A.- Analisis univariado

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
plt.figure(figsize=(20, 20))

for i, columna in enumerate(df_num, start=1):
    plt.subplot(8, 4, i)
    sns.histplot(data=df, x=columna)
    plt.tight_layout()

# %%
sns.countplot(data=df, x='diagnosis')
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
plt.figure(figsize=(20, 20))

for i, columna in enumerate(df_num, start=1):
    plt.subplot(8, 4, i)
    sns.boxplot(data=df, x=columna)
    plt.tight_layout()

# %% [markdown]
# ### B.- Analisis bivariado

# %%
plt.figure(figsize=(20, 20))

for i, columna in enumerate(df_num, start=1):
    plt.subplot(8, 4, i)
    sns.histplot(data=df, x=columna, hue='diagnosis')
    plt.tight_layout()

# %%
sns.pairplot(data=df.iloc[:, :7], hue='diagnosis')

# %%
plt.figure(figsize=(20, 10))

sns.heatmap(df[df_num].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# * los datos tienen una distrubucion pero parecen sesgadas a la derecha
# * las clase diagnosis parece diferenciable, ya que suelen tener un valor mas alto
# * hay algunos valores extremos
# * hay bastantes valores correlacionados, lo que es entendible si hablamos del tamaño del tumor o del craneo

# %% [markdown]
# ## 2.- Preprocesamiento

# %% [markdown]
# ### A.- Division del dataset

# %%
x = df.drop('diagnosis', axis=1)
y = df['diagnosis']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ### B.- Transformacion

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = pd.DataFrame(scaler.fit_transform(x_train), columns=x_train.columns)
x_test = pd.DataFrame(scaler.transform(x_test), columns=x_test.columns)

# %%
from sklearn.preprocessing import LabelEncoder

lab_encoder = LabelEncoder()
y_train = lab_encoder.fit_transform(y_train)
y_test = lab_encoder.transform(y_test)

# %% [markdown]
# ### C.- Seleccion de caracteristicas

# %%
from sklearn.ensemble import RandomForestClassifier

tree_model = RandomForestClassifier()

tree_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
tree_model.feature_importances_
# Out:
# array([0.00517593, 0.03994467, 0.01019266, 0.09005035, 0.03885453,
#        0.00806475, 0.00911282, 0.04139674, 0.11402875, 0.00436232,
#        0.0030355 , 0.02308377, 0.00996857, 0.01140596, 0.03615883,
#        0.00318826, 0.00563825, 0.00485846, 0.00314299, 0.00330976,
#        0.00513049, 0.08094287, 0.02365652, 0.1160177 , 0.12823146,
#        0.00909776, 0.0100397 , 0.03098578, 0.11637564, 0.00931297,
#        0.00523524])

# %%
df_importancias = pd.DataFrame({
    'feature': list(x_train), 
    'importance': tree_model.feature_importances_
    }).sort_values(by='importance',ascending=False)

# %%
df_importancias
# Out:
#                     feature  importance
# 24               area_worst    0.128231
# 28     concave points_worst    0.116376
# 23          perimeter_worst    0.116018
# 8       concave points_mean    0.114029
# 3            perimeter_mean    0.090050
# 21             radius_worst    0.080943
# 7            concavity_mean    0.041397
# 1               radius_mean    0.039945
# 4                 area_mean    0.038855
# 14                  area_se    0.036159
# 27          concavity_worst    0.030986
# 22            texture_worst    0.023657
# 11                radius_se    0.023084
# 13             perimeter_se    0.011406
# 2              texture_mean    0.010193
# 26        compactness_worst    0.010040
# 12               texture_se    0.009969
# 29           symmetry_worst    0.009313
# 6          compactness_mean    0.009113
# 25         smoothness_worst    0.009098
# 5           smoothness_mean    0.008065
# 16           compactness_se    0.005638
# ...

# %%
sns.barplot(data=df_importancias, x='importance', y='feature')
# Out:
# <Axes: xlabel='importance', ylabel='feature'>

# %%
df_importancias['feature'][:11]
# Out:
# 24              area_worst
# 28    concave points_worst
# 23         perimeter_worst
# 8      concave points_mean
# 3           perimeter_mean
# 21            radius_worst
# 7           concavity_mean
# 1              radius_mean
# 4                area_mean
# 14                 area_se
# 27         concavity_worst
# Name: feature, dtype: object

# %%
x_train = x_train[df_importancias['feature'][:11]]
x_test= x_test[df_importancias['feature'][:11]]

# %% [markdown]
# ## 3.- Entrenamiento

# %% [markdown]
# ### A.- Seleccion del modelo

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB


models = {
    'lr_model': LogisticRegression(),
    'tree': DecisionTreeClassifier(),
    'rf_model': RandomForestClassifier(),
    'svc': SVC(),
    'naive bayes': GaussianNB(),
}

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

resultado =  []

for name, model in models.items():
    model.fit(x_train, y_train)

    y_pred = model.predict(x_test)

    acccuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    resultado.append({'model': name, 'acurracy': acccuracy, 'precision': precision, 'recall': recall, 'f1_score': f1})

# %%
metricas_df = pd.DataFrame(resultado)
metricas_df
# Out:
#          model  acurracy  precision    recall  f1_score
# 0     lr_model  0.912281   0.833333  0.921053  0.875000
# 1         tree  0.929825   0.857143  0.947368  0.900000
# 2     rf_model  0.938596   0.897436  0.921053  0.909091
# 3          svc  0.947368   0.921053  0.921053  0.921053
# 4  naive bayes  0.938596   0.897436  0.921053  0.909091

# %%
metrics = ['acurracy', 'precision', 'recall','f1_score']

plt.figure(figsize=(25, 4))
for i, metric in enumerate(metrics, start=1):
    plt.subplot(1, 4, i)
    sns.barplot(data=metricas_df, x='model', y=metric)

# %% [markdown]
# ### B.- Busqueda de hiperparametros

# %%
hiperparametros = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],  
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], 
    'max_iter': [100, 200, 300, 400, 500, 1000, 2000],         
    'tol': [1e-4, 1e-3, 1e-2, 1e-1],                
    'class_weight': [None, 'balanced']              
}

# %%
from sklearn.model_selection import GridSearchCV

lr_model = GridSearchCV(estimator=LogisticRegression(), param_grid=hiperparametros, cv=5)

lr_model.fit(x_train, y_train)
# Out:
# /home/davian/ml-proyects/.conda/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/davian/ml-proyects/.conda/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/davian/ml-proyects/.conda/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/davian/ml-proyects/.conda/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/davian/ml-proyects/.conda/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
lr_model.best_params_
# Out:
# {'class_weight': None,
#  'max_iter': 1000,
#  'penalty': 'l1',
#  'solver': 'liblinear',
#  'tol': 0.001}

# %% [markdown]
# ## 4.- Evaluacion

# %%
y_pred = lr_model.predict(x_test)

print(
    'acurracy: ', accuracy_score(y_test, y_pred),
    '\nprecision: ', precision_score(y_test, y_pred),
    '\nrecall: ', recall_score(y_test, y_pred),
    '\nf1 score', f1_score(y_test, y_pred) 
)
# Out:
# acurracy:  0.9035087719298246
# precision:  0.813953488372093
# recall:  0.9210526315789473
# f1 score 0.8641975308641975

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, xticklabels=['c. 0', 'c. 1',], yticklabels=['c. 0', 'c. 1'])
plt.xlabel("Predicción")
plt.ylabel("Real")
# Out:
# Text(50.722222222222214, 0.5, 'Real')
